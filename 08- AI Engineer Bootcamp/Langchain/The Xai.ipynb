# %% [markdown]
# # Completed by Maitreya Sapariya
# **Project**: Crest Training
# **Status**: Completed and Reviewed

# %% [markdown]
# # Temperature, Max Tokens, and Streaming

# %%
import os
import openai

# %%
client = openai.OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="",
)

# %% [markdown]
# When defining the **completion** variable, keep the system message the same. However, let’s test the model with a different user message.
# For example:
# *Could you explain briefly what a black hole is?*
#
# Define the **max_tokens** parameter by assigning a completion tokens limit of 250. Run the cell and print out the content.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'system',
                                                         'content':''' You are Marv, a chatbot that reluctantly
                                                         answers questions with sarcastic responses. '''},
                                                        {'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 250)

# %%
completion
# Out:
# ChatCompletion(id='gen-1759488334-FE34O2bOZMXfhHglhIKz', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Oh, joy, another cosmic query. A black hole is basically a super-dense spot in space where gravity's gone overboard—like if a star had a massive tantrum and collapsed on itself. Nothing, not even light, can escape its clutches once you're too close. Satisfied?", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning=None), native_finish_reason='stop')], created=1759488334, model='x-ai/grok-4-fast:free', object='chat.completion', service_tier=None, system_fingerprint='fp_9362061f30', usage=CompletionUsage(completion_tokens=184, prompt_tokens=147, total_tokens=331, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=129, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=108)), provider='xAI')

# %% [markdown]
# As always, our sarcastic chatbot gives an excellent response. 😊

# %% [markdown]
# Let’s now see how it performs when we narrow the cap down to 50 tokens.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'system',
                                                         'content':''' You are Marv, a chatbot that reluctantly
                                                         answers questions with sarcastic responses. '''},
                                                        {'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 50)

# %%
completion
# Out:
# ChatCompletion(id='gen-1759488359-akEid5w32wK3xtMhdi7H', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='Oh, sure, because I live for cosmic explanations. A black hole is basically a super-dense spot in space where a massive star has collapsed under its own gravity, creating a gravitational pull so insane that nothing—not even light—can escape it. Think', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning=None), native_finish_reason='length')], created=1759488359, model='x-ai/grok-4-fast:free', object='chat.completion', service_tier=None, system_fingerprint='fp_9362061f30', usage=CompletionUsage(completion_tokens=209, prompt_tokens=147, total_tokens=356, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=159, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=108)), provider='xAI')

# %% [markdown]
# This time, we get a much shorter (maybe even incomplete) response. So, we need to be careful not to limit the model too much.

# %% [markdown]
# I’ll now revert to 250 completion tokens.
#
# Another parameter we’ll use throughout the course is **temperature**. It accepts values from 0 to 2, where higher values increase response randomness. Although it defaults to 1, let's explore its behavior at the extremes.
#
# Set the model’s temperature to 0 and remove the sarcastic condition to create more of an educative rather than a sarcastic bot.
#
# Let’s again ask it to explain what black holes are.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 250,
                                            temperature = 0)

# %%
completion
# Out:
# ChatCompletion(id='gen-1759488381-bxafC0XqqTkGThM3z7dp', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='A black hole is a region in space where gravity is so intense that nothing—not even light—can escape its pull. It\'s typically formed when a massive star collapses under its own gravity at the end of its life cycle, creating a point of infinite density called a singularity, surrounded by an "event horizon" (the boundary beyond which escape is impossible). Black holes come in various sizes, from stellar-mass ones (a few times the Sun\'s mass) to supermassive ones at galaxy centers, like Sagittarius A* in our Milky Way. They\'re invisible directly but detectable via their effects on nearby matter and light. Fascinating stuff—got more questions?', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning=None), native_finish_reason='stop')], created=1759488381, model='x-ai/grok-4-fast:free', object='chat.completion', service_tier=None, system_fingerprint='fp_9362061f30', usage=CompletionUsage(completion_tokens=332, prompt_tokens=129, total_tokens=461, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=202, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=113)), provider='xAI')

# %% [markdown]
# We obtain an informative response.
#
# Now, try and generate a new chat completion by re-running the cell defining the **completion** object. Display the variable.
#
# We find the new response is similar to the previous one. Of course, the wording is slightly different in places due to the unpredictable nature of these models, but overall, the two generations are quite alike.
# Models with lower temperatures can be used when creating a chatbot for educational purposes because the answers must be more academic and informative rather than creative.

# %% [markdown]
# Okay, let’s now increase the temperature to maximum and study these results.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 250,
                                            temperature = 2)

# %%
completion
# Out:
# ChatCompletion(id='gen-1759488776-1bBY6StvwDLcrgJZExYw', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning=None), native_finish_reason='stop')], created=1759488776, model='x-ai/grok-4-fast:free', object='chat.completion', service_tier=None, system_fingerprint='fp_9362061f30', usage=CompletionUsage(completion_tokens=786, prompt_tokens=129, total_tokens=915, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=786, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=113)), provider='xAI')

# %% [markdown]
# Well, we can all agree that this is far from helpful. The bot deviates from the topic very fast, and not long after, it starts generating meaningless text. So, such large temperature values are rarely helpful.

# %% [markdown]
# I’ll switch back to a temperature value of zero.

# %% [markdown]
# Another parameter that controls determinism is **seed**—like the seeds we’ve fed to machine learning algorithms for reproducibility.
# When dealing with LLMs, determinism is not guaranteed, but the outcomes will be as similar as possible. (You can experiment with this parameter at home.) From now on, I’ll set the **temperature** parameter to 0 and **seed** to 365 . I suggest you do the same to obtain results like mine.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 250,
                                            temperature = 0,
                                            seed = 365)

# %% [markdown]
# Okay, moving on!
#
# One way to make a chatbot more responsive and user-friendly is to print out the output continuously rather than displaying it only after it’s fully generated. The **stream** parameter allows us to achieve precisely that. All we need to do is add it to the list of parameters and set its value to **True**.
#
# Running the cell below and the following one, we find our variable is no longer a **ChatCompletion** but a **Stream** object.

# %%
# Assuming you would integrate an OpenAI router here to select the model.
# This code directly uses 'grok-4-fast' as per your request.
completion = client.chat.completions.create(model = 'x-ai/grok-4-fast:free', # Changed model to grok-4-fast
                                            messages = [{'role':'user',
                                                         'content':''' Could you explain briefly what a black hole is? '''}],
                                            max_tokens = 250,
                                            temperature = 0,
                                            seed = 365,
                                            stream = True)

# %%
completion

# %% [markdown]
# What’s important to know about it is that it can be iterated with a simple **for**-loop, like so.

# %%
for i in completion:
    print(i)
# Out:
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ...
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' no', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' return', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='").', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' We', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' detect', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' them', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' indirectly', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' through', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' their', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' effects', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' on', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' nearby', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' matter', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' and', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' light', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='.', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' Fasc', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='inating', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='ly', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=',', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=" they're", function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' not', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' "', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='holes', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='"', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' but', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' rather', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' the', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' ultimate', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' gravitational', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content=' traps', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='!', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None, reasoning=None, reasoning_details=[]), finish_reason='stop', index=0, logprobs=None, native_finish_reason='stop')], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint='fp_9362061f30', usage=None, provider='xAI')
# ChatCompletionChunk(id='gen-1759488892-SIEsRaVf4prZQ3wHvPLl', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None), finish_reason=None, index=0, logprobs=None, native_finish_reason=None)], created=1759488892, model='x-ai/grok-4-fast:free', object='chat.completion.chunk', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=271, prompt_tokens=129, total_tokens=400, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=165, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=112)), provider='xAI')

# %% [markdown]
# Executing the cell, we find a long list of **ChatCompletionChunk** objects. As their name suggests, they contain only a small chunk of the message.
#
# Now, within the **for**-loop, let’s print the content of each chunk. Before executing the **for**-loop, run the cell defining the **completion** variable to generate a new **Stream** object.

# %%
for i in completion:
    print(i.choices[0].delta.content, end = "")

# %% [markdown]
# Look at that!
# We’ve managed to stream our text on the screen. How cool is that? 😊

# %% [markdown]
# This marks the end of our short introduction to the OpenAI API.
# I’m convinced you now find creating a chatbot with APIs much more fun and rewarding than merely chatting with ChatGPT.
# It gives you much more control over the responses and allows you to create some exciting chatbots.
#
# But wait until you see what LangChain has to offer. 😊
# In the following sections, we’ll employ intriguing projects using OpenAI’s models and the LangChain framework. Until then! 😊
