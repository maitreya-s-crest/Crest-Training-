# %% [markdown]
# **Getting Started With Python Bootcamp**

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# **Introduction to Variables**

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income + tax_rate

# %%
my_taxes
# Out:
# 100.1

# %% [markdown]
# **Introduction to Strings**

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
'I am working as a Trainee at Crest InfoSystems'
# Out:
# 'I am working as a Trainee at Crest InfoSystems'

# %%
print ("Hello \nSurat")
# Out:
# Hello
# Surat

# %%
print ("Hello \tSurat")
# Out:
# Hello 	Surat

# %%
len ("Maitreya")
# Out:
# 8

# %% [markdown]
# **String Indexing & Slicing**

# %%
mystring = "Hello Surat"

# %%
mystring
# Out:
# 'Hello Surat'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[9]
# Out:
# 'a'

# %%
mystring[-1]
# Out:
# 't'

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]  # Does not include index 3(stop before 3)
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::2]  # step size 2, jumps of 2
# Out:
# 'acegik'

# %%
mystring [::-1]  # reverse string trick
# Out:
# 'kjihgfedcba'

# %% [markdown]
# **Immutability**

# %%
name = "Sam"

# %%
last_letters = name[1:]

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
X = 'Hello Surat !'

# %%
X + " It is beautiful day today."
# Out:
# 'Hello Surat ! It is beautiful day today.'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
X = 'Hello Surat'

# %%
X.upper()
# Out:
# 'HELLO SURAT'

# %%
X  # Does not change original string
# Out:
# 'Hello Surat'

# %%
X.lower()
# Out:
# 'hello surat'

# %%
X.split()  # splits into a list
# Out:
# ['Hello', 'Surat']

# %%
X = "My name is Maitreya"
X.split()
# Out:
# ['My', 'name', 'is', 'Maitreya']

# %%
X.split('i') # splits at i
# Out:
# ['My name ', 's Ma', 'treya']

# %% [markdown]
# **Print Formatting with Strings**

# %%
print('My name is Maitreya {}' .format('SAPARIYA'))
# Out:
# My name is Maitreya SAPARIYA

# %%
print('The  {} {} {}' .format('fox', 'brown', 'quick') )
# Out:
# The  fox brown quick

# %%
print('The  {1} {0} {2}' .format('fox', 'brown', 'quick') )
# Out:
# The  brown fox quick

# %%
result = 100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print ("The result was {r}" .format(r=result))
# Out:
# The result was 0.1287001287001287

# %%
name = "Maitreya"

# %%
print(f'Hello, my name is {name}') # f-string way, use curly braces {}
# Out:
# Hello, my name is Maitreya

# %%
name = "Maitreya"
age = 21

# %%
print (f"{name} is {age} years old.")
# Out:
# Maitreya is 21 years old.

# %% [markdown]
# **LISTS**

# %%
my_list = [1,2,3]

# %%
my_list = ['MAITREYA', 100, 14.9]

# %%
len(my_list)
# Out:
# 3

# %%
my_list = ['one', 'two', 'three']

# %%
my_list [0]
# Out:
# 'one'

# %%
another_list = ['four', 'five']

# %%
new_list = my_list + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'Maitreya'

# %%
new_list
# Out:
# ['Maitreya', 'two', 'three', 'four', 'five']

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['Maitreya', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.pop()
# Out:
# 'six'

# %%
new_list
# Out:
# ['Maitreya', 'two', 'three', 'four', 'five']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'five'

# %%
new_list.pop(0)
# Out:
# 'Maitreya'

# %%
new_list
# Out:
# ['two', 'three', 'four']

# %%
new_list = ['a', 'b', 'x', 'd', 'e']
num_list = [1,2,3,4,5]

# %%
type(new_list)
# Out:
# list

# %%
num_list.reverse()

# %%
num_list
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# **DICTIONARIES**

# %%
# Dictionaries - Retrieved by key name
#Unordered and cannot be sorted

# %%
my_dict = {'key1': 'value1', 'key2': 'value2' }

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
Prices = {'Apple': '2.99' , 'Oranges': '1.99'}

# %%
Prices['Apple']
# Out:
# '2.99'

# %%
d = {'k1': 100, 'k2': 200}

# %%
d ['k3'] = 300

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d['k1'] = 'NEW VALUE'

# %%
d
# Out:
# {'k1': 'NEW VALUE', 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values(['NEW VALUE', 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 'NEW VALUE'), ('k2', 200), ('k3', 300)])

# %% [markdown]
# **TUPLES**

# %%
#Tuples are immutable in nature, cannot be changed

# %%
t = (1,2,3)

# %%
list = [1,2,3]

# %%
type (t)
# Out:
# tuple

# %%
type(list)
# Out:
# list

# %%
t = ('one', 2)

# %%
t
# Out:
# ('one', 2)

# %%
t = ('a' , 'a' , 'b')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
t
# Out:
# ('a', 'a', 'b')

# %% [markdown]
# **Sets**

# %%
# Unordered collection of Uniques elements

# %%
myset= set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
mylist = [1,1,2,2,3,3,3]

# %%
set(my_list)
# Out:
# {'one', 'three', 'two'}

# %% [markdown]
# **Booleans**

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type (False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %% [markdown]
# **FIle I/O Operations**

# %%
# mode='r' is read only
# mode='w' is write only
# mode='a' is append only
# mode='r+' is reading and writing
# mode='w+' is writing and reading

# %%
# %%writefile myfile.txt
# Hello this is a text file
# This is the second line
# This is third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
pwd
# Out:
# 'c:\\Users\\MaitreyaSapariya\\Desktop\\Training\\Crest-Training-\\01- Python Bootcamp\\03- Python Object and Data Structure Basics'

# %%
myfile = open ('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file \nThis is the second line \nThis is third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file \nThis is the second line \nThis is third line\n'

# %%
pwd
# Out:
# 'c:\\Users\\MaitreyaSapariya\\Desktop\\Training\\Crest-Training-\\01- Python Bootcamp\\03- Python Object and Data Structure Basics'

# %%
myfile.close()

# %%
with open ('myfile.txt', mode = 'r') as myfile:
    contents = myfile.read()

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
contents
# Out:
# 'Hello this is a text file \nThis is the second line \nThis is third line\n'
