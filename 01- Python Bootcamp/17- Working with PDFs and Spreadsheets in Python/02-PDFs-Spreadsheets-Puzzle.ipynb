# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # PDFs and Spreadsheets Puzzle Exercise
#
# Let's test your skills, the files needed for this puzzle exercise
#
# You will need to work with files for this exercise and solve the following tasks:
#
# * Task One: Download the PDF from the Google Drive link (we already downloaded it for you just in case you can't download from Google Drive) and find the phone number that is in the document. Note: There are different ways of formatting a phone number!

# %% [markdown]
# ## Task One: Download the PDF from the Google Drive link and find the phone number that is in the document.

# %%
import PyPDF2

# %%
f = open('Find_the_Phone_Number.pdf','rb')
pdf = PyPDF2.PdfReader(f)
len(pdf.pages)
# Out:
# 17

# %%
import re

# %%
pattern = r'\d{3}.\d{3}.\d{4}' 
for n in range(len(pdf.pages)):
    
    page  = pdf.pages[n]
    page_text = page.extract_text()
    match = re.search(pattern,page_text)
    
    if match:
        print(match.group())
# Out:
# 505.503.4455
