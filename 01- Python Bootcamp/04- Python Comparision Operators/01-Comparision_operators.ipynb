# %% [markdown]
# **Comparision Operators**

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
'Hello' == 'Bye'
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
3 < 5
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %% [markdown]
# **Logical Operators**

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 == 1 or 2 == 3
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
not (1 ==1 )
# Out:
# False

# %%
not 4000 > 5000
# Out:
# True
