# %%
import pandas as pd
# Create dataframe
data = {'Company':['GOOG','GOOG','NVIDIA','MSFT','FB','FB'],
       'Person':['Markie','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG   Markie    200
# 1    GOOG  Charlie    120
# 2  NVIDIA      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company')

# %%
by_comp = df.groupby("Company")

# %%
by_comp.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 by_comp.mean()
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\internals\managers.py:1629, in BlockManager.grouped_reduce(self, func)
#    1627             result_blocks = extend_blocks(applied, result_blocks)
#    1628     else:
# -> 1629         applied = blk.apply(func)
#    1630         result_blocks = extend_blocks(applied, result_blocks)
#    1632 if len(result_blocks) == 0:
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\ops.py:957, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     953 assert kind in ["transform", "aggregate"]
#     955 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 957 return cy_op.cython_operation(
#     958     values=values,
#     959     axis=axis,
#     960     min_count=min_count,
#     961     comp_ids=self.ids,
#     962     ngroups=self.ngroups,
#     963     **kwargs,
#     964 )
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\arrays\base.py:2755, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2741 if isinstance(self.dtype, StringDtype):
#    2742     # StringArray
#    2743     if op.how in [
#    2744         "prod",
#    2745         "mean",
#    (...)   2753         "kurt",
#    2754     ]:
# -> 2755         raise TypeError(
#    2756             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2757         )
#    2758     if op.how not in ["any", "all"]:
#    2759         # Fail early to avoid conversion to object
#    2760         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
df.groupby('Company').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.groupby('Company').mean()
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\internals\managers.py:1629, in BlockManager.grouped_reduce(self, func)
#    1627             result_blocks = extend_blocks(applied, result_blocks)
#    1628     else:
# -> 1629         applied = blk.apply(func)
#    1630         result_blocks = extend_blocks(applied, result_blocks)
#    1632 if len(result_blocks) == 0:
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\ops.py:957, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     953 assert kind in ["transform", "aggregate"]
#     955 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 957 return cy_op.cython_operation(
#     958     values=values,
#     959     axis=axis,
#     960     min_count=min_count,
#     961     comp_ids=self.ids,
#     962     ngroups=self.ngroups,
#     963     **kwargs,
#     964 )
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\07- Python for Machine Learning & Data Science\venv\Lib\site-packages\pandas\core\arrays\base.py:2755, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2741 if isinstance(self.dtype, StringDtype):
#    2742     # StringArray
#    2743     if op.how in [
#    2744         "prod",
#    2745         "mean",
#    (...)   2753         "kurt",
#    2754     ]:
# -> 2755         raise TypeError(
#    2756             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2757         )
#    2758     if op.how not in ["any", "all"]:
#    2759         # Fail early to avoid conversion to object
#    2760         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT     Vanessa    124
# NVIDIA       Amy    340

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG      Markie    200
# MSFT     Vanessa    124
# NVIDIA       Amy    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          1      1
# NVIDIA        1      1

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      1.0  124.0        NaN  124.0  124.00  124.0  124.00  124.0
# NVIDIA    1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG   MSFT  NVIDIA
# Sales count    2.000000    2.000000    1.0     1.0
#       mean   296.500000  160.000000  124.0   340.0
#       std     75.660426   56.568542    NaN     NaN
#       min    243.000000  120.000000  124.0   340.0
#       25%    269.750000  140.000000  124.0   340.0
#       50%    296.500000  160.000000  124.0   340.0
#       75%    323.250000  180.000000  124.0   340.0
#       max    350.000000  200.000000  124.0   340.0

# %%
by_comp.describe().transpose()['GOOG']
# Out:
# Sales  count      2.000000
#        mean     160.000000
#        std       56.568542
#        min      120.000000
#        25%      140.000000
#        50%      160.000000
#        75%      180.000000
#        max      200.000000
# Name: GOOG, dtype: float64
