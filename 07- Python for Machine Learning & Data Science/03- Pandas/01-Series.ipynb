# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\maitreyasapariya\desktop\training\crest-training-\07- python for machine learning & data science\venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maitreyasapariya\desktop\training\crest-training-\07- python for machine learning & data science\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\maitreyasapariya\desktop\training\crest-training-\07- python for machine learning & data science\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 883.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.9 MB 995.7 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 995.7 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 995.7 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 995.7 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.9 MB 752.3 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/9.9 MB 752.3 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/9.9 MB 752.3 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/9.9 MB 752.3 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/9.9 MB 752.3 kB/s eta 0:00:11
#    -------- ------------------------------- 2.1/9.9 MB 565.7 kB/s eta 0:00:14
#    -------- ------------------------------- 2.1/9.9 MB 565.7 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.9 MB 549.5 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.6/9.9 MB 358.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 2.6/9.9 MB 358.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 2.6/9.9 MB 358.1 kB/s eta 0:00:21
#    ----------- ---------------------------- 2.9/9.9 MB 354.9 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.9/9.9 MB 354.9 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.9/9.9 MB 354.9 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.9/9.9 MB 354.9 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.9/9.9 MB 354.9 kB/s eta 0:00:20
#    ------------ --------------------------- 3.1/9.9 MB 346.7 kB/s eta 0:00:20
#    ------------- -------------------------- 3.4/9.9 MB 363.7 kB/s eta 0:00:18
#    ------------- -------------------------- 3.4/9.9 MB 363.7 kB/s eta 0:00:18
#    ------------- -------------------------- 3.4/9.9 MB 363.7 kB/s eta 0:00:18
#    -------------- ------------------------- 3.7/9.9 MB 369.2 kB/s eta 0:00:17
#    -------------- ------------------------- 3.7/9.9 MB 369.2 kB/s eta 0:00:17
#    --------------- ------------------------ 3.9/9.9 MB 375.4 kB/s eta 0:00:16
#    --------------- ------------------------ 3.9/9.9 MB 375.4 kB/s eta 0:00:16
#    ----------------- ---------------------- 4.2/9.9 MB 386.8 kB/s eta 0:00:15
#    ------------------ --------------------- 4.5/9.9 MB 401.9 kB/s eta 0:00:14
#    ------------------ --------------------- 4.5/9.9 MB 401.9 kB/s eta 0:00:14
#    ------------------ --------------------- 4.5/9.9 MB 401.9 kB/s eta 0:00:14
#    ------------------- -------------------- 4.7/9.9 MB 408.3 kB/s eta 0:00:13
#    -------------------- ------------------- 5.0/9.9 MB 422.2 kB/s eta 0:00:12
#    -------------------- ------------------- 5.0/9.9 MB 422.2 kB/s eta 0:00:12
#    -------------------- ------------------- 5.0/9.9 MB 422.2 kB/s eta 0:00:12
#    ---------------------- ----------------- 5.5/9.9 MB 441.1 kB/s eta 0:00:10
#    ----------------------- ---------------- 5.8/9.9 MB 457.7 kB/s eta 0:00:09
#    ------------------------ --------------- 6.0/9.9 MB 468.9 kB/s eta 0:00:09
#    ------------------------ --------------- 6.0/9.9 MB 468.9 kB/s eta 0:00:09
#    ------------------------- -------------- 6.3/9.9 MB 470.1 kB/s eta 0:00:08
#    -------------------------- ------------- 6.6/9.9 MB 483.6 kB/s eta 0:00:07
#    ---------------------------- ----------- 7.1/9.9 MB 515.0 kB/s eta 0:00:06
#    ----------------------------- ---------- 7.3/9.9 MB 530.6 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.3/9.9 MB 530.6 kB/s eta 0:00:05
#    ------------------------------ --------- 7.6/9.9 MB 530.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.6/9.9 MB 530.1 kB/s eta 0:00:05
#    -------------------------------- ------- 8.1/9.9 MB 547.1 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 547.1 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 547.1 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 547.1 kB/s eta 0:00:04
#    ----------------------------------- ---- 8.7/9.9 MB 540.6 kB/s eta 0:00:03
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 546.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 517.9 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 517.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.9 MB 528.1 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 528.1 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 528.0 kB/s  0:00:18
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-3.0.0 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a Series

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(labels,my_list)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: str

# %% [markdown]
# #### NumPy Arrays

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# #### Dictionary

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### Data in a Series

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: str

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# ## Using an Index

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# np.int64(1)

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64
