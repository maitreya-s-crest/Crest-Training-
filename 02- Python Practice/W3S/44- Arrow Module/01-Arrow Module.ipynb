# %% [markdown]
# **1. Get hourly datetime between two hours**
#
# Write a Python program to get hourly datetime between two hours.

# %%
# !pip install arrow
# Out:
# Collecting arrow
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\maitreyasapariya\desktop\training\crest-training-\02- python practice\w3s\venv\lib\site-packages (from arrow) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\maitreyasapariya\desktop\training\crest-training-\02- python practice\w3s\venv\lib\site-packages (from arrow) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\maitreyasapariya\desktop\training\crest-training-\02- python practice\w3s\venv\lib\site-packages (from python-dateutil>=2.7.0->arrow) (1.17.0)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Installing collected packages: arrow
# Successfully installed arrow-1.4.0

# %%
import arrow

# %%
a = arrow.utcnow()
print("Current datetime:")
print(a)
# Out:
# Current datetime:
# 2026-01-16T11:58:49.257746+00:00

# %%
print("\nString representing the date, controlled by an explicit format string:")
print(arrow.utcnow().strftime('%d-%m-%Y %H:%M:%S'))
# Out:
# String representing the date, controlled by an explicit format string:
# 16-01-2026 11:58:50

# %%
print(arrow.utcnow().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2026-01-16 11:58:51

# %%
print(arrow.utcnow().strftime('%Y-%d-%m %H:%M:%S'))
# Out:
# 2026-16-01 11:58:52
