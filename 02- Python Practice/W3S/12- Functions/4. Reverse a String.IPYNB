# %% [markdown]
# **4. Reverse a String**
#
# Problem Statement: Write a Python program to reverse a string.
#
# Sample String: "1234abcd"

# %%
str = '1234abcd'
reversed_str = str [: : -1]
print (reversed_str)
# Out:
# dcba4321
