# %% [markdown]
# **21. Age Calculation using Pendulum**
#
# Problem Statement:
# Write a Python program to **calculate a person’s age** from their **birthdate** using the `pendulum` module, which provides enhanced date and time handling.

# %%
# !pip install pendulum
# Out:
# Collecting pendulum
#   Downloading pendulum-3.1.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\maitreyasapariya\desktop\training\crest-training-\02- python practice\w3s\venv\lib\site-packages (from pendulum) (2.9.0.post0)
# Collecting tzdata>=2020.1 (from pendulum)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\maitreyasapariya\desktop\training\crest-training-\02- python practice\w3s\venv\lib\site-packages (from python-dateutil>=2.6->pendulum) (1.17.0)
# Downloading pendulum-3.1.0-py3-none-any.whl (111 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pendulum
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pendulum]
#    -------------------- ------------------- 1/2 [pendulum]
#    -------------------- ------------------- 1/2 [pendulum]
#    -------------------- ------------------- 1/2 [pendulum]
#    -------------------- ------------------- 1/2 [pendulum]
#    ---------------------------------------- 2/2 [pendulum]
#
# Successfully installed pendulum-3.1.0 tzdata-2025.3

# %%
import pendulum

# %%
def calculate_age(birth_date):
    current_date = pendulum.now()
    birthdate = pendulum.parse(birth_date)
    age = current_date.diff(birthdate).in_years()
    return age

# %%
birthdate_str = "2004-09-14"
person_age = calculate_age(birthdate_str)
print(f"The person's age with birthdate {birthdate_str} is {person_age} years.")
# Out:
# The person's age with birthdate 2004-09-14 is 21 years.
