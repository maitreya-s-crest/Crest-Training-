# %% [markdown]
# **5. Fibonacci Sequence Using Recursion**
#
# Problem Statement: Write a Python program to solve the Fibonacci sequence using recursion using recursion.

# %%
def fibonacci (n):
    if n == 1 or n == 2:
        return 1 
    else:
        return fibonacci (n - 1) + fibonacci (n - 2)

print (fibonacci(7))
# Out:
# 13
