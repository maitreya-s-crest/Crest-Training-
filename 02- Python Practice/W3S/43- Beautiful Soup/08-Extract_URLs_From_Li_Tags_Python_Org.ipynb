# %% [markdown]
# **8. Task: Extract URLs from `<li>` Tags on Python.org Webpage**
#
# Problem Statement:
# Write a Python program that extracts all the URLs that are nested within `<li>` tags from the webpage "https://www.python.org".

# %%
# !pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [soupsieve]
#    -------------------- ------------------- 2/4 [beautifulsoup4]
#    ---------------------------------------- 4/4 [bs4]
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://python.org/"

# %%
reqs = requests.get(url)

# %%
soup = BeautifulSoup(reqs.text, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 soup = BeautifulSoup(reqs.text, 'lxml')
#
# File c:\Users\MaitreyaSapariya\Desktop\Training\Crest-Training-\02- Python Practice\W3S\venv\Lib\site-packages\bs4\__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
#     373 # At this point either we have a TreeBuilder instance in
# ...

# %%
urls = []

# %%
for h in soup.find_all('li'):
    a = h.find('a')
    urls.append(a.attrs['href'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for h in soup.find_all('li'):
#       2     a = h.find('a')
#       3     urls.append(a.attrs['href'])
#
# NameError: name 'soup' is not defined

# %%
print(urls)
# Out:
# []
