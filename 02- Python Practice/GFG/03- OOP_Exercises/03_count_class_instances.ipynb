# %% [markdown]
# <span style="font-size: 22px;">**Task: Count Number of Instances of a Class in Python**</span>
#
# Problem Statement:
# Determine how many instances (objects) of a class have been created in Python during runtime.

# %%
class instance_count():
    counter = 0 

    def __init__(self):
        instance_count.counter += 1

# %%
list1 = instance_count()

# %%
list2 = instance_count()

# %%
list3 = instance_count()

# %%
print(instance_count.counter)
# Out:
# 3
