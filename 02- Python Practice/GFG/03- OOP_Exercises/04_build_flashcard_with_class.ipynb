# %% [markdown]
# <span style="font-size: 22px;">**Task: Build Flashcard Using Class in Python**</span>
#
# Problem Statement:
# Create a flashcard system in Python using classes. Each flashcard should contain a word and its meaning, enabling easy display and review.

# %%
class Flashcard():
    def __init__(self, word, meaning):
        self.word = word
        self.meaning = meaning

    def __str__(self):
        return self.word+ '('+self.meaning+')'

# %%
flash = []

# %%
while(True):
    word = input("Enter the word you want to add to the flashcard: ")
    meaning = input("Enter the meaning of the word: ")

    flash.append(Flashcard(word,meaning))

    option = int(input("enter 0 , if you want to add another flashcard : "))

    if(option):
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       3 meaning = input("Enter the meaning of the word: ")
#       5 flash.append(Flashcard(word,meaning))
# ----> 7 option = int(input("enter 0 , if you want to add another flashcard : "))
#       9 if(option):
#      10     break
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print("\nYour flashcards")
for i in flash:
    print(">", i)
# Out:
# Your flashcards
# > dsa (ALGORITHM)(GFG (Geeks for geeks))
# > Erasmus Mundus Scholarship - Maitreya 2027(Reasearch Paper Published)
# > ()
# > Research Paper Published - (2026)(Erasmus Mundus Scholarship - Maitreya (2027))
